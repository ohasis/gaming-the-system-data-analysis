# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Timeline

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 11/1  |  5 PM | Read & Consider COGS 108 Expectations; Brainstorm Topics & Questions  | Determine Best Form of Communication; Discuss & Decide on Project Topic; Discuss Hypothesis; Begin Background Research |
# | 11/1  |  5 PM |  Do Background Research on Topic | Discuss Ideal Dataset(s) & Ethics; Draft Project Proposal |
# | 11/1  | 5 PM  | Edit, Finalize, & Submit Proposal; Search for Datasets  | Discuss Wrangling & Possible Analytical Approaches; Assign Group Members to Lead Each Part   |
# | 11/8  | 5 PM  | Import & Wrangle Data (Anish); EDA (Artemis) | Review & Edit Wrangling/EDA; Discuss Analysis Plan   |
# | 11/29  | 5 PM  | Finalize Wrangling/EDA; Begin Analysis (Ethan & Dayoung) | Discuss & Edit Analysis; Complete Project Check-In |
# | 12/6  | 5 PM  | Complete Analysis; Draft Results, Conclusion, & Discussion (Pranav)| Discuss & Edit Full Project |
# | 12/13  | Before 11:59 PM  | N/A | Turn in Final Project & Group Project Surveys |

# %% [markdown]
# # Names
#
# - Anish Devineni
# - Ethan Heffernan
# - Dayoung Ki
# - Artemis Lopez
# - Pranav Nair

# %% [markdown]
# # Research Question

# %% [markdown]
# **Are there certain combinations of video game genres that consistently earn more positive reviews, higher overall ratings, and increased sales, based on critic and user scores and copies sold? Can genres be feasibly used as predictors for success as measured by these two variables?**

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The gaming industry has seen tremendous growth over the past few decades, with a diverse selection of genres available to players all over the world. The reception of these games, both initial and long-term, which are reflected in user and critic reviews, along with their sales performance is of significant interest to the developers creating these games, as well as the gaming community which depends on many of these statistics to make their decisions on what to purchase or play. Understanding how these factors interact, particularly across different game genres, is in the best interest of developers and publishers aiming to align their products with market demands and player preferences.
#
# Regarding previous research work that has been performed in this domain, previous work has primarily been focused on analyzing the impact of reviews on sales. One particular study, a research study performed by Feray Adigüzel of Nottingham Trent University in September of 2021 suggests a strong correlation between positive reviews of games through formats such as YouTube videos, and to what extent these opinions shared with large audiences affect the sales of different games <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1). Additionally, the project “Data Trends in Video Game Sales and Ratings” created by Casey Hoffman in 2021 <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) conducted an analysis of multiple research questions in the same space, most relevantly “Are user and critic ratings correlated, for different genres?” and “Do either user or critic ratings correlate with game sales?” Both of these questions address related questions to ours; however, they do not discuss our question: how do genre combinations affect the relationship between review scores and sales numbers?
#
# For some more context, research published by researchers from Illinois Wesleyan University <a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) explored various determinants of video game software sales. While it didn't specifically discuss genre combinations, it laid a foundation for understanding consumer preferences and how they translate to sales, which could be instrumental in analyzing how genre combinations might sway consumer perceptions and sales. Similarly, a report by a researcher at Duke University in 2019 <a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4) aimed to identify factors influencing the success of video game sales. It provides a broad framework within which the impact of genre combinations could be analyzed, although it doesn’t specifically delve into genre combinations. This work could serve as a reference point for structuring a more focused investigation into how genre combinations affect sales performance​
#
# In terms of further analysis in this field, the insights derived from potential further research might be instrumental in guiding developers towards creating games that not only resonate with their target audience but also understand which characteristics tend to lead to commercial success while doing so. The discussed data shows how game genres, reviews, and sales are connected, but not much is found about how mixing genres affects these areas. Our analysis aims to fill this gap. We want to explore how combining genres impacts both user and critic reviews, and how this affects sales. Our analysis seeks to add a new angle to the existing information, helping to better understand how genre combinations work in the gaming market.
#
# <br />
# <br />
#
#
#
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Adigűzel, Feray. (Sep. 2021) The Effect of YouTube Reviews on Video Game Sales. *ResearchGate*. https://www.researchgate.net/publication/353737385_The_Effect_of_YouTube_Reviews_on_Video_Game_Sales
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Hoffman, Casey. (7 Feb. 2021) Data Trends in Video Game Sales and Ratings. *NYC Data Science Academy*. https://nycdatascience.com/blog/student-works/data-trends-in-video-game-sales-and-ratings/
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Sacranie, John. (23 Apr. 2010) Consumer Perceptions & Video Game Sales: A Meeting of the Minds. *Illinois Wesleyan University*. https://digitalcommons.iwu.edu/econ_honproj/108
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Soriano Pérez, Sebastián. (10 Dec. 2019) Analyzing Video Game Sales. *Duke University*. https://www.academia.edu/42255674/Analyzing_Video_Game_Sales

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We predict that genre popularity (operationalized as the aggregate total of sales of titles within that particular genre, the most number of positive reviews in comparison to the other genres in the sample, and the highest overall game ratings) will generate an effect on the relationship between these variables and their independent variables: critic and user scores and copies of games sold within that particular genre.
#
# This is based on our theory that video game titles with mass-market appeal will belong to certain genres wherein the critical reviews are more correlated to hypothesized commercial appeal rather than more niche genres where critics will only be interested in reviewing if they have a pre-existing interest in the genre, potentially diverging their reviews from sales.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data Overview
#
# Our ideal dataset that would be most relevant in answering our research question would be an integration of data from multiple relevant datasets ranging from some containing data from video game reviews, and some from video game reviews or demographics, or some from video game sales. The variables that we would be considering the most in our analysis would be the genre and subgenre categories of certain games, the ratings of games within these genres, the size of the developers that produce these games, and the sales or commercial performance of these different game categories over time. Ideally, this data would be collected by an unbiased source which takes into account all factors of reviews, and considers all different types of genres for games, as well as considers a variety of different games developed by varying sizes of game development companies. This data would also ideally not need much cleaning, and would consist og complete, relevant values, and would contain thousands of samples for us to consider to decrease any sort of variance in our analysis.
#
# From the datasets that we have already found that are relevant to the analysis we are attempting to complete, there are over 10,000+ observations in the most limited set of data, giving us an ample amount of data to begin building our analysis. This data has been collected previously by other developers who have created scripts to scrape reviews and sales data from popular sites such as Metacritic. This data is so far, in fact, somewhat different than our ideal, as it is limited in the information it provides for sales over time, or reviews over time, and instead provides general sales and general ratings, but it does provide genres and subgenres of games, developer companies, and user/critic reviews.  \
#   \
#   \
# **Dataset Links:**  \
#   \
# [Video Game Sales with Ratings - Kaggle](https://www.kaggle.com/datasets/rush4ratio/video-game-sales-with-ratings)  \
#   \
# [Popular Video Games 1980 - 2023 - Kaggle](https://www.kaggle.com/datasets/arnabchaki/popular-video-games-1980-2023/data)
#
# - Dataset #1
#   - Dataset Name: Video Game Sales as of December 22, 2016
#   - Link to the dataset: [Video Game Sales with Ratings - Kaggle](https://www.kaggle.com/datasets/rush4ratio/video-game-sales-with-ratings)
#   - Number of observations: 267,502
#   - Number of variables: 14
#   - Description: This dataset contains data on a wide assortment of video games that have been released from 1980 to 2016. The data contains identifying information on each game, such as the genre, release date, etc. The variables that can be considered important include genre, all variables related to sales, critic score, and user score. Non-numerical data are recorded as strings, numerical variables such as release date, critic score, and counts are recorded as integers, and remaining numerical data are recorded floats.
# - Dataset #2 (if you have more than one!)
#   - Dataset Name: Popular Video Games 1980 - 2023
#   - Link to the dataset: [Popular Video Games 1980 - 2023 - Kaggle](https://www.kaggle.com/datasets/arnabchaki/popular-video-games-1980-2023/data)
#   - Number of observations: 267,472
#   - Number of variables: 16
#   - Description: This dataset contains a list of video games released from 1980 to 2023. It also includes information such as the released date, average rating, number of reviews received from the users, user reviews, etc. User reviews, the summary provided by the team, all genres about a specified game, and the game developer team in this dataset are stored as strings while numerical variables are stored as floats.
#
# We plan to combine both datasets to give ourselves more variables to analyze, which is especially helpful given that our research question intends to address how genre combinations translate to differences in the sentiment of reviews, developer ratings, and sales. We will clean both datasets separately but focus specifically on the variables mentioned above when analyzing the data. After combining them, we will do a final check to ensure that everything looks alright before certifying them to begin analysis. Utilizing both datasets together will give us the chance to seamlessly plot information and draw conclusions much more easily than we would if they were separate.

# %% [markdown]
# ## popular_games_user_reviews.csv

# %%
import pandas as pd 
import sklearn as sk
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

df_reviews = pd.read_csv('data/popular_games_user_reviews.csv') 
df_reviews.columns

str()

# %%
df_reviews = df_reviews.drop_duplicates(['Title', 'Release Date'])
df_reviews = df_reviews.dropna(subset=['Title', 'Reviews', 'Rating'])
df_reviews = df_reviews.drop(columns='Unnamed: 0', axis=1)

df_reviews.head(3)
# Out:
#                                      Title  Release Date  \
# 0                               Elden Ring  Feb 25, 2022
# 1                                    Hades  Dec 10, 2019
# 2  The Legend of Zelda: Breath of the Wild  Mar 03, 2017
#
#                                                 Team  Rating Times Listed  \
# 0     ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# 1                               ['Supergiant Games']     4.3         2.9K
# 2  ['Nintendo', 'Nintendo EPD Production Group No...     4.4         4.3K
#
#   Number of Reviews                                    Genres  \
# 0              3.9K                      ['Adventure', 'RPG']
# 1              2.9K  ['Adventure', 'Brawler', 'Indie', 'RPG']
# 2              4.3K                      ['Adventure', 'RPG']
#
#                                              Summary  \
# 0  Elden Ring is a fantasy, action and open world...
# 1  A rogue-lite hack and slash dungeon crawler in...
# 2  The Legend of Zelda: Breath of the Wild is the...
#
#                                              Reviews Plays Playing Backlogs  \
# 0  ["The first playthrough of elden ring is one o...   17K    3.8K     4.6K
# 1  ['convinced this is a roguelike for people who...   21K    3.2K     6.3K
# 2  ['This game is the game (that is not CS:GO) th...   30K    2.5K       5K
#
#   Wishlist
# 0     4.8K
# 1     3.6K
# 2     2.6K

# %%
def num_convert(string):
    string = string.lower()
    string = string.strip()
    if 'k' in string:
        string = string.replace('k', '')
        return float(string) * 1000
    else:
        return float(string)

columns_to_convert = ['Times Listed', 'Number of Reviews', 'Plays', 'Playing', 'Backlogs', 'Wishlist']

for column in columns_to_convert:
    df_reviews[column] = df_reviews[column].apply(num_convert)

df_reviews.head()
# Out:
#                                      Title  Release Date  \
# 0                               Elden Ring  Feb 25, 2022
# 1                                    Hades  Dec 10, 2019
# 2  The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                Undertale  Sep 15, 2015
# 4                            Hollow Knight  Feb 24, 2017
#
#                                                 Team  Rating  Times Listed  \
# 0     ['Bandai Namco Entertainment', 'FromSoftware']     4.5        3900.0
# 1                               ['Supergiant Games']     4.3        2900.0
# 2  ['Nintendo', 'Nintendo EPD Production Group No...     4.4        4300.0
# 3                                 ['tobyfox', '8-4']     4.2        3500.0
# 4                                    ['Team Cherry']     4.4        3000.0
#
#    Number of Reviews                                             Genres  \
# 0             3900.0                               ['Adventure', 'RPG']
# 1             2900.0           ['Adventure', 'Brawler', 'Indie', 'RPG']
# 2             4300.0                               ['Adventure', 'RPG']
# 3             3500.0  ['Adventure', 'Indie', 'RPG', 'Turn Based Stra...
# 4             3000.0                 ['Adventure', 'Indie', 'Platform']
#
#                                              Summary  \
# 0  Elden Ring is a fantasy, action and open world...
# 1  A rogue-lite hack and slash dungeon crawler in...
# 2  The Legend of Zelda: Breath of the Wild is the...
# 3  A small child falls into the Underground, wher...
# 4  A 2D metroidvania with an emphasis on close co...
#
#                                              Reviews    Plays  Playing  \
# 0  ["The first playthrough of elden ring is one o...  17000.0   3800.0
# 1  ['convinced this is a roguelike for people who...  21000.0   3200.0
# 2  ['This game is the game (that is not CS:GO) th...  30000.0   2500.0
# 3  ['soundtrack is tied for #1 with nier automata...  28000.0    679.0
# 4  ["this games worldbuilding is incredible, with...  21000.0   2400.0
#
#    Backlogs  Wishlist
# 0    4600.0    4800.0
# 1    6300.0    3600.0
# 2    5000.0    2600.0
# 3    4900.0    1800.0
# 4    8300.0    2300.0

# %% [markdown]
# ## video_game_sales_with_ratings.csv

# %%
df_sales = pd.read_csv("data/video_game_sales_with_ratings.csv")

df_sales = df_sales.rename(columns={'Name': 'Title'})
df_sales = df_sales.rename(columns={'Year_of_Release': 'Release Date'})
df_sales = df_sales.drop_duplicates(['Title', 'Release Date', 'Platform'])
df_sales = df_sales.dropna(subset=['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'])

df_sales.head()
# Out:
#                       Title Platform  Release Date         Genre Publisher  \
# 0                Wii Sports      Wii        2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES        1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii        2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii        2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB        1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis

# %% [markdown]
# ### EDA Section 1

# %%
print("reviews_df:",df_reviews.dtypes, '\n\n')
print("sales_df:", df_sales.dtypes)
# Out:
# reviews_df: Title                 object
# Release Date          object
# Team                  object
# Rating               float64
# Times Listed         float64
# Number of Reviews    float64
# Genres                object
# Summary               object
# Reviews               object
# Plays                float64
# Playing              float64
# Backlogs             float64
# Wishlist             float64
# dtype: object
#
#
# sales_df: Title            object
# Platform         object
# Release Date    float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# Critic_Score    float64
# Critic_Count    float64
# User_Score       object
# User_Count      float64
# Developer        object
# Rating           object
# dtype: object

# %%
sns.pairplot(df_reviews)
# Out:
# /Users/eeunicekki/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# plot number of reviews with respect to rating
sns.scatterplot(data=df_reviews, x = 'Rating', y = 'Number of Reviews')
# Out:
# <Axes: xlabel='Rating', ylabel='Number of Reviews'>

# %%
Y = df_reviews['Number of Reviews']
X = df_reviews['Rating']
X = sm.add_constant(X)
model = sm.OLS(Y,X)
results = model.fit()
results.params

sns.regplot(x='Rating', y='Number of Reviews', data = df_reviews)
# Out:
# <Axes: xlabel='Rating', ylabel='Number of Reviews'>

# %%
X.head()
Y.head()
#coef = np.polyfit(X, np.log(Y), 1)
#a, b = coef
#print(coef)
# Out:
# 0    3900.0
# 1    2900.0
# 2    4300.0
# 3    3500.0
# 4    3000.0
# Name: Number of Reviews, dtype: float64

# %% [markdown]
# ### EDA Section 2

# %%
reviews_columns = ['Title', 'Rating', 'Genres', 'Reviews']
df_reviews_data = df_reviews[reviews_columns]
df_reviews_data.shape
#df_reviews_data.head(3)
# Out:
# (1104, 4)

# %%
sales_columns = ['Title', 'Global_Sales', 'Critic_Score', 'User_Score']
df_sales_data = df_sales[sales_columns]
df_sales_data.shape
#df_sales_data.head(3)
# Out:
# (16717, 4)

# %%
merged_df = pd.merge(df_reviews_data, df_sales_data, on='Title', how='inner')
merged_df.shape
#merged_df.head()
merged_df.head(50)
# Out:
#                              Title  Rating  \
# 0                        Minecraft     4.3
# 1                        Minecraft     4.3
# 2                        Minecraft     4.3
# 3                        Minecraft     4.3
# 4                        Minecraft     4.3
# 5                        Minecraft     4.3
# 6                        Minecraft     4.2
# 7                        Minecraft     4.2
# 8                        Minecraft     4.2
# 9                        Minecraft     4.2
# 10                       Minecraft     4.2
# 11                       Minecraft     4.2
# 12                      God of War     4.2
# 13                      God of War     3.6
# 14                        Portal 2     4.4
# 15                        Portal 2     4.4
# 16                        Portal 2     4.4
# 17                      Bloodborne     4.5
# 18  Metal Gear Rising: Revengeance     4.1
# 19  Metal Gear Rising: Revengeance     4.1
# 20              Grand Theft Auto V     3.8
# 21              Grand Theft Auto V     3.8
# 22              Grand Theft Auto V     3.8
# 23              Grand Theft Auto V     3.8
# 24              Grand Theft Auto V     3.8
# 25                  Dark Souls III     4.2
# 26                  Dark Souls III     4.2
# 27                  Dark Souls III     4.2
# 28                  Super Mario 64     4.1
# 29                  Super Mario 64     4.1
# 30               Final Fantasy VII     4.2
# 31               Final Fantasy VII     4.2
# 32              Super Mario Galaxy     4.3
# 33              Fallout: New Vegas     4.3
# 34              Fallout: New Vegas     4.3
# 35              Fallout: New Vegas     4.3
# 36                 Resident Evil 2     4.3
# 37                 Resident Evil 2     4.3
# 38                 Resident Evil 2     4.3
# 39                 Resident Evil 2     4.2
# 40                 Resident Evil 2     4.2
# 41                 Resident Evil 2     4.2
# 42                            Doom     4.0
# 43                            Doom     4.0
# 44                            Doom     4.0
# 45                            Doom     4.0
# 46                            Doom     4.0
# 47                            Doom     4.0
# 48                            Doom     3.9
# 49                            Doom     3.9
#
#                                              Genres  \
# 0                        ['Adventure', 'Simulator']
# 1                        ['Adventure', 'Simulator']
# 2                        ['Adventure', 'Simulator']
# 3                        ['Adventure', 'Simulator']
# 4                        ['Adventure', 'Simulator']
# 5                        ['Adventure', 'Simulator']
# 6                        ['Adventure', 'Simulator']
# 7                        ['Adventure', 'Simulator']
# 8                        ['Adventure', 'Simulator']
# 9                        ['Adventure', 'Simulator']
# 10                       ['Adventure', 'Simulator']
# 11                       ['Adventure', 'Simulator']
# 12                  ['Adventure', 'Brawler', 'RPG']
# 13             ['Adventure', 'Brawler', 'Strategy']
# 14   ['Adventure', 'Platform', 'Puzzle', 'Shooter']
# 15   ['Adventure', 'Platform', 'Puzzle', 'Shooter']
# 16   ['Adventure', 'Platform', 'Puzzle', 'Shooter']
# 17                             ['Adventure', 'RPG']
# 18  ['Adventure', 'Brawler', 'Shooter', 'Strategy']
# 19  ['Adventure', 'Brawler', 'Shooter', 'Strategy']
# 20                         ['Adventure', 'Shooter']
# 21                         ['Adventure', 'Shooter']
# 22                         ['Adventure', 'Shooter']
# 23                         ['Adventure', 'Shooter']
# 24                         ['Adventure', 'Shooter']
# 25                             ['Adventure', 'RPG']
# 26                             ['Adventure', 'RPG']
# 27                             ['Adventure', 'RPG']
# 28                        ['Adventure', 'Platform']
# 29                        ['Adventure', 'Platform']
# 30      ['Adventure', 'RPG', 'Turn Based Strategy']
# 31                   ['RPG', 'Turn Based Strategy']
# 32                        ['Adventure', 'Platform']
# 33                               ['RPG', 'Shooter']
# 34                               ['RPG', 'Shooter']
# 35                               ['RPG', 'Shooter']
# 36                         ['Adventure', 'Shooter']
# 37                         ['Adventure', 'Shooter']
# 38                         ['Adventure', 'Shooter']
# 39                         ['Adventure', 'Shooter']
# 40                         ['Adventure', 'Shooter']
# 41                         ['Adventure', 'Shooter']
# 42                                      ['Shooter']
# 43                                      ['Shooter']
# 44                                      ['Shooter']
# 45                                      ['Shooter']
# 46                                      ['Shooter']
# 47                                      ['Shooter']
# 48                                      ['Shooter']
# 49                                      ['Shooter']
#
#                                               Reviews  Global_Sales  \
# 0   ['Minecraft is what you make of it. Unfortunat...          9.18
# 1   ['Minecraft is what you make of it. Unfortunat...          5.26
# 2   ['Minecraft is what you make of it. Unfortunat...          4.32
# 3   ['Minecraft is what you make of it. Unfortunat...          2.76
# 4   ['Minecraft is what you make of it. Unfortunat...          1.96
# 5   ['Minecraft is what you make of it. Unfortunat...          0.68
# 6   ['have never played minecraft a day in my life...          9.18
# 7   ['have never played minecraft a day in my life...          5.26
# 8   ['have never played minecraft a day in my life...          4.32
# 9   ['have never played minecraft a day in my life...          2.76
# 10  ['have never played minecraft a day in my life...          1.96
# 11  ['have never played minecraft a day in my life...          0.68
# 12  ['freya te vejo como figura materna', 'i ruv !...          4.45
# 13  ['As a god of war game, It s incredible\n     ...          4.45
# 14  ['This is my fav game of all time, everything ...          2.08
# 15  ['This is my fav game of all time, everything ...          1.70
# 16  ['This is my fav game of all time, everything ...          0.76
# 17  ["I'm not trying to brag, but Bloodborne wasn'...          2.48
# 18  ['This game is so jank but so entertaining', '...          1.42
# 19  ['This game is so jank but so entertaining', '...          0.48
# 20  ['People be rating this a 3.... BITCH BE SERIO...         21.04
# 21  ['People be rating this a 3.... BITCH BE SERIO...         16.27
# 22  ['People be rating this a 3.... BITCH BE SERIO...         12.61
# 23  ['People be rating this a 3.... BITCH BE SERIO...          5.48
# 24  ['People be rating this a 3.... BITCH BE SERIO...          1.17
# 25  ['The only soulsborne game I dont ever want to...          1.65
# 26  ['The only soulsborne game I dont ever want to...          0.39
# 27  ['The only soulsborne game I dont ever want to...          0.07
# 28  ['We all know the importance of this game and ...         11.89
# 29  ['We all know the importance of this game and ...         10.30
# 30  ['I bought this game on Nintendo Switch with a...          9.72
# 31  ["The ugliest game I've ever played.", 'Hands ...          9.72
# 32  ['They got rid of the fun part', "bro this gam...         11.35
# 33  ["The only bad part of this game is Matthew Pe...          4.05
# 34  ["The only bad part of this game is Matthew Pe...          3.11
# 35  ["The only bad part of this game is Matthew Pe...          1.17
# 36  ["I remember not thinking too much about the o...          5.82
# 37  ["I remember not thinking too much about the o...          0.56
# 38  ["I remember not thinking too much about the o...          0.06
# 39  ['A product of the time, but the tank controls...          5.82
# 40  ['A product of the time, but the tank controls...          0.56
# 41  ['A product of the time, but the tank controls...          0.06
# 42  ['Recomendado (aunque se hace muy repetitivo)'...          0.78
# 43  ['Recomendado (aunque se hace muy repetitivo)'...          0.14
# 44  ['Recomendado (aunque se hace muy repetitivo)'...          0.03
# 45  ['Recomendadisimo', 'classic', 'doom my belove...          0.78
# 46  ['Recomendadisimo', 'classic', 'doom my belove...          0.14
# 47  ['Recomendadisimo', 'classic', 'doom my belove...          0.03
# 48  ['can we get a Doom anime. Now I would watch t...          0.78
# 49  ['can we get a Doom anime. Now I would watch t...          0.14
#
#     Critic_Score User_Score
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 8            NaN        NaN
# 9            NaN        NaN
# 10           NaN        NaN
# 11           NaN        NaN
# 12          94.0        8.9
# 13          94.0        8.9
# 14          95.0        8.5
# 15          95.0        8.4
# 16          95.0        8.8
# 17          92.0        8.6
# 18          80.0        7.9
# 19          82.0        7.8
# 20          97.0        8.2
# 21          97.0        8.1
# 22          97.0        8.3
# 23          97.0        7.9
# 24          96.0        7.9
# 25          89.0        8.8
# 26          87.0        8.6
# 27          89.0        8.6
# 28           NaN        NaN
# 29           NaN        NaN
# 30          92.0        9.2
# 31          92.0        9.2
# 32          97.0        8.9
# 33          84.0        8.1
# 34          82.0        7.8
# 35          84.0        8.6
# 36          89.0        9.2
# 37           NaN        NaN
# 38          59.0        8.5
# 39          89.0        9.2
# 40           NaN        NaN
# 41          59.0        8.5
# 42           NaN        NaN
# 43          81.0        8.5
# 44          85.0        8.2
# 45           NaN        NaN
# 46          81.0        8.5
# 47          85.0        8.2
# 48           NaN        NaN
# 49          81.0        8.5

# %% [markdown]
# To easily visualize the connections among overall ratings, increased sales, and critical reviews from developers, the scatterplots below depict their relationships.

# %%
sns.scatterplot(data=merged_df, x = 'Critic_Score', y = 'Rating')
sns.regplot(data=merged_df, x='Critic_Score', y='Rating', scatter=False, color='red')

plt.xlabel('Critic_Score')
plt.ylabel('Rating')

plt.show()

# %%
sns.scatterplot(data=merged_df, x = 'Critic_Score', y = 'Global_Sales')

sns.regplot(data=merged_df, x='Critic_Score', y='Global_Sales', scatter=False, color='red')

plt.xlabel('Critic_Score')
plt.ylabel('Global_Sales')

plt.show()

# %% [markdown]
# As illustrated, both the relationship between ratings and critic scores, as well as global sales and critic scores, exhibit positive trend lines. Both graphs depict that a higher critic score is likely to correlate with higher ratings and increased copies sold.
#
# Next, we'll explore the connection between the average total ratings per game genre.

# %%
list_of_genres_ratings = ['Brawler', 'Platform', 'Shooter', 'Adventure', 'Puzzle', 'RPG', 'Strategy', 'Simulator', 'Turn Based Strategy']

# Filtering the data frame for each genre and storing the calculated average ratings
average_ratings = []
for genre in list_of_genres_ratings:
    filtered_genre = merged_df[merged_df['Genres'].str.contains(genre)]
    average_ratings.append(filtered_genre['Rating'].mean())

plt.figure(figsize=(10, 6))
plt.barh(list_of_genres_ratings, average_ratings)
plt.xlabel('Average Rating')
plt.ylabel('Genre')
plt.title('Average Rating per Genre')
plt.xlim(3.5, 4.0)  # Set y-axis limit

plt.tight_layout()
plt.show()

# %% [markdown]
# When considering the average ratings per genre, the Turn-Based Strategy genre had the highest average ratings, followed by Simulator. On the other hand, Brawler holds the lowest average rating, followed by Platform. Nevertheless, the average rating across all genres did not fall below 3.5.
#
# We also took a look at the correlation between average critic score across different game genres.

# %%
list_of_genres_CS = ['Brawler', 'Platform', 'Puzzle', 'Adventure', 'Simulator', 'Strategy', 'Shooter', 'RPG', 'Turn Based Strategy']

# Filtering the data frame for each genre and storing the calculated average critic score
average_critic_score = []
for genre in list_of_genres_CS:
    filtered_genre = merged_df[merged_df['Genres'].str.contains(genre)]
    average_critic_score.append(filtered_genre['Critic_Score'].mean())

plt.figure(figsize=(10, 6))
plt.barh(list_of_genres_CS, average_critic_score)
plt.xlabel('Average Critic Score')
plt.ylabel('Genre')
plt.title('Average Critic Score per Genre')
plt.xlim(76, 86)  # Set x-axis limit

plt.tight_layout()
plt.show()

# %% [markdown]
# Turn-Based Strategy maintained the highest average critic score. However, Shooter ranked third in average critic scores, yet it landed as the third lowest in the average rating.
#
# Additionally, Brawler and Platform retained the lowest average critic scores, aligning once more with their standings in the average rating analysis.
#
# Adventure and Puzzle also kept their place in the low-mid place. Adventure and Puzzle continued to occupy the lower to mid-tier positions in both graphs, suggesting a similar trend across both critical evaluations and user ratings for most genres.

# %%
list_of_genres_GS = ['Turn Based Strategy', 'Strategy', 'Brawler', 'Puzzle', 'RPG', 'Platform', 'Shooter', 'Adventure']

# Filtering the data frame for each genre and storing the calculated total global sales
total_global_sales = []
for genre in list_of_genres_GS:
    filtered_genre = merged_df[merged_df['Genres'].str.contains(genre)]
    total_global_sales.append(filtered_genre['Global_Sales'].sum())

plt.figure(figsize=(10, 6))
plt.barh(list_of_genres_GS, total_global_sales)
plt.xlabel('Total Global Sales (in millions of units)')
plt.ylabel('Genre')
plt.title('Total Global Sales per Genre')
plt.ylim(-0.5, len(list_of_genres_GS) - 0.5)  # Adjust y-axis limits for better visibility

plt.tight_layout()
plt.show()

# %% [markdown]
# The graph above illustrates that despite Turn-Based Strategy having the highest average ratings and average critic score, it recorded the lowest total global sales across all genres.
#
# Strategy, which was placed in high-mid place for previous graphs, also secured the second-lowest position in total global sales.
#
# Interestingly, Adventure secured the highest sales, while Platform ranked third in sales, despite both genres receiving relatively low average ratings and critic scores. This disparity between critical evaluations, user ratings, and consumer preferences suggest that sales performance may not correlate direclty with critical assessments or average ratings.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# - The data files that our group used are publicly available on Kaggle, which is a publicly accessible site.
# - For the games in question, players must sign end-user license agreements before playing.
#     - This measure establishes an agreement between the player and developer to ensure that the relative popularity of the game—for example, the number of downloads—is assessable and reviewers may translate it into a numerical score.
# - To expound on this fact, the potential bias that may have occurred when the data was collected includes the following:
#     - Customers who did not have a good experience with the video game are more likely to leave a review than those who had a good experience.
#     - More casual players may leave rational reviews comprehensive by the general public, while more frequent players of other genres may leave irrational reviews.
#     - Encountering other players’ reviews may have affected the players' review whether it is positive or negative.
# - Data variation may be unavoidable when analyzing data since that would lead to the collection of user-specific data which introduces privacy concerns.
#
# __How can we counteract these issues?__
#
# Without knowing more about the game reviewers themselves, it is difficult to limit the biases that may have affected their reviews. However, by taking a random sample of the reviews, we are working to minimize the effect of these biases in our dataset. For reviews in other languages, our NLP methods could be used to translate these reviews to English before performing sentiment analysis to avoid completely ignoring reviews from different languages, as these reviews may offer insights into opinions from different countries and markets.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# * Each team member will be assigned a task to complete each week and will be expected to complete said task in a timely manner.
# * Team members should communicate with other members about their progress; it doesn’t have to be super often, just enough to where everybody knows what’s going on.
# * If a team member is unable to complete their assigned task, they should communicate to the rest of the team as early as possible so that everyone else can work to get the work done.
# * If a team member is being uncooperative, active efforts will be made to communicate this to them, such as a meeting, or written message in the form of email, text, etc, before communicating with the professor
# * Each team member will do their part in communicating if they have any roadblocks to the team
# * Each team member will be willing to extend help to other team members in times of struggle or confusion to accomplish the task at hand
